# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install transformers torchvision torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.54.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.34.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.7.14)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 68.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 59.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 8.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 107.2 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127

# %%
import os
from PIL import Image
import torch
from torchvision import transforms
from transformers import BeitFeatureExtractor, BeitModel

# Load the BEiT feature extractor and model
feature_extractor = BeitFeatureExtractor.from_pretrained('microsoft/beit-base-patch16-224')
model = BeitModel.from_pretrained('microsoft/beit-base-patch16-224')

# Set model to evaluation mode
model.eval()

# Directory path
image_dir = "/content/drive/MyDrive/Autistic Children Emotions - Dr. Fatma M. Talaat/Train"

# Image preprocessing
preprocess = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=feature_extractor.image_mean, std=feature_extractor.image_std)
])

# Function to extract features
def extract_features(image_path):
    image = Image.open(image_path).convert("RGB")
    pixel_values = feature_extractor(images=image, return_tensors="pt").pixel_values
    with torch.no_grad():
        outputs = model(pixel_values)
    last_hidden_state = outputs.last_hidden_state  # Shape: [1, 197, 768]
    cls_embedding = last_hidden_state[:, 0]         # [CLS] token embedding
    return cls_embedding.squeeze().numpy()

# Example: Extract features from all images in folder
features = {}
for root, _, files in os.walk(image_dir):
    for file in files:
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            path = os.path.join(root, file)
            try:
                features[file] = extract_features(path)
                print(f"Extracted features for {file}")
            except Exception as e:
                print(f"Error processing {file}: {e}")

# Optional: Save features to disk
import pickle
with open("autistic_children_beit_features.pkl", "wb") as f:
    pickle.dump(features, f)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/276 [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/models/beit/feature_extraction_beit.py:28: FutureWarning: The class BeitFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use BeitImageProcessor instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/utils/deprecation.py:172: UserWarning: The following named arguments are not valid for `BeitFeatureExtractor.__init__` and were ignored: 'feature_extractor_type'
#   return func(*args, **kwargs)
# config.json:   0%|          | 0.00/69.9k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/350M [00:00<?, ?B/s]
# Extracted features for 0004.jpg
# Extracted features for 0015.jpg
# Extracted features for 0075.jpg
# Extracted features for 0028.jpg
# Extracted features for 0036.jpg
# Extracted features for 0087.jpg
# Extracted features for 0077.jpg
# Extracted features for 0006.jpg
# Extracted features for 0046.jpg
# Extracted features for 0008.jpg
# Extracted features for 0098.jpg
# Extracted features for 0052.jpg
# Extracted features for 0042.jpg
# Extracted features for 0045.jpg
# Extracted features for 0005.jpg
# Extracted features for 0058.jpg
# Extracted features for 0071.jpg
# Extracted features for 0081.jpg
# Extracted features for 0029.jpg
# Extracted features for 0361.jpg
# Extracted features for 0613.jpg
# Extracted features for 0602.jpg
# Extracted features for 0805.jpg
# Extracted features for 0166.jpg
# Extracted features for 0943.jpg
# Extracted features for 1245.jpg
# Extracted features for 0615.jpg
# Extracted features for 0641.jpg
# Extracted features for 0118.jpg
# Extracted features for 0193.jpg
# Extracted features for 0402.jpg
# Extracted features for 0260.jpg
# Extracted features for 0115.jpg
# Extracted features for 0804.jpg
# Extracted features for 0638.jpg
# Extracted features for 0690.jpg
# Extracted features for 0722.jpg
# Extracted features for 0644.jpg
# Extracted features for 0950.jpg
# Extracted features for 0700.jpg
# Extracted features for 0600.jpg
# Extracted features for 0800.jpg
# Extracted features for 0628.jpg
# Extracted features for 0184.jpg
# Extracted features for 0552.jpg
# Extracted features for 0114.jpg
# Extracted features for 0188.jpg
# Extracted features for 0363.jpg
# Extracted features for 0142.jpg
# Extracted features for 0629.jpg
# Extracted features for 0161.jpg
# Extracted features for 1290.jpg
# Extracted features for 1261.jpg
# Extracted features for 1254.jpg
# Extracted features for 1258.jpg
# Extracted features for 1291.jpg
# Extracted features for 1313.jpg
# Extracted features for 1263.jpg
# Extracted features for 1257.jpg
# Extracted features for 1256.jpg
# Extracted features for 1262.jpg
# Extracted features for 1255.jpg
# Extracted features for 1259.jpg
# Extracted features for 0191.jpg
# Extracted features for 0203.jpg
# Extracted features for 0186.jpg
# Extracted features for 0255.jpg
# Extracted features for 0225.jpg
# Extracted features for 0158.jpg
# Extracted features for 0194.jpg
# Extracted features for 0200.jpg
# Extracted features for 0034.jpg
# Extracted features for 0035.jpg
# Extracted features for 0181.jpg
# Extracted features for 0131.jpg
# Extracted features for 0125.jpg
# Extracted features for 0153.jpg
# Extracted features for 0094.jpg
# Extracted features for 0154.jpg
# Extracted features for 0187.jpg
# Extracted features for 0197.jpg
# Extracted features for 0175.jpg
# Extracted features for 0146.jpg
# Extracted features for 0056.jpg
# Extracted features for 0091.jpg
# Extracted features for 0424.jpg
# Extracted features for 0265.jpg
# Extracted features for 0417.jpg
# Extracted features for 0841.jpg
# Extracted features for 0362.jpg
# Extracted features for 0423.jpg
# Extracted features for 0523.jpg
# Extracted features for 0299.jpg
# Extracted features for 0711.jpg
# Extracted features for 0307.jpg
# Extracted features for 0623.jpg
# Extracted features for 0288.jpg
# Extracted features for 0283.jpg
# Extracted features for 0281.jpg
# Extracted features for 0292.jpg
# Extracted features for 0842.jpg
# Extracted features for 0291.jpg
# Extracted features for 0507.jpg
# Extracted features for 0366.jpg
# Extracted features for 0274.jpg
# Extracted features for 0348.jpg
# Extracted features for 0290.jpg
# Extracted features for 0449.jpg
# Extracted features for 0296.jpg
# Extracted features for 0368.jpg
# Extracted features for 0838.jpg
# Extracted features for 0300.jpg
# Extracted features for 0682.jpg
# Extracted features for 0833.jpg
# Extracted features for 0822.jpg
# Extracted features for 0285.jpg
# Extracted features for 0313.jpg
# Extracted features for 0899.jpg
# Extracted features for 0919.jpg
# Extracted features for 1267.jpg
# Extracted features for 1247.jpg
# Extracted features for 0948.jpg
# Extracted features for 0914.jpg
# Extracted features for 0954.jpg
# Extracted features for 1249.jpg
# Extracted features for 1248.jpg
# Extracted features for 1018.jpg
# Extracted features for 1038.jpg
# Extracted features for 1308.jpg
# Extracted features for 0890.jpg
# Extracted features for 0138.png
# Extracted features for 0085.jpg
# Extracted features for 0168.jpg
# Extracted features for 0037.jpg
# Extracted features for 0049.jpg
# Extracted features for 0048.jpg
# Extracted features for 0095.jpg
# Extracted features for 0093.jpg
# Extracted features for 0080.jpg
# Extracted features for 0144.jpg
# Extracted features for 0104.jpg
# Extracted features for 0025.jpg
# Extracted features for 0033.jpg
# Extracted features for 0038.jpg
# Extracted features for 0111.jpg
# Extracted features for 0177.jpg
# Extracted features for 0164.jpg
# Extracted features for 0179.jpg
# Extracted features for 0069.jpg
# Extracted features for 0451.jpg
# Extracted features for 1257.jpg
# Extracted features for 1259.jpg
# Extracted features for 0427.jpg
# Extracted features for 1255.jpg
# Extracted features for 1254.jpg
# Extracted features for 0405.jpg
# Extracted features for 0420.jpg
# Extracted features for 0493.jpg
# Extracted features for 1258.jpg
# Extracted features for 1256.jpg
# Extracted features for 0035.jpg
# Extracted features for 0016.jpg
# Extracted features for 0034.jpg
# Extracted features for 0063.jpg
# Extracted features for 0026.jpg
# Extracted features for 0027.jpg
# Extracted features for 0038.jpg
# Extracted features for 0058.jpg
# Extracted features for 0023.jpg
# Extracted features for 0056.jpg
# Extracted features for 0031.jpg
# Extracted features for 0049.jpg
# Extracted features for 0011.jpg
# Extracted features for 0047.jpg
# Extracted features for 0054.jpg
# Extracted features for 0033.jpg
# Extracted features for 0044.jpg
# Extracted features for 0010.jpg
# Extracted features for 0025.jpg
# Extracted features for 0048.jpg
# Extracted features for 0021.jpg
# Extracted features for 0037.jpg
# Extracted features for 0055.jpg
# Extracted features for 0059.jpg
# Extracted features for 0073.jpg
# Extracted features for 0106.jpg
# Extracted features for 0084.jpg
# Extracted features for 0122.jpg
# Extracted features for 0144.jpg
# Extracted features for 0095.jpg
# Extracted features for 0099.jpg
# Extracted features for 0161.jpg
# Extracted features for 0164.jpg
# Extracted features for 0072.jpg
# Extracted features for 0125.jpg
# Extracted features for 0131.jpg
# Extracted features for 0093.jpg
# Extracted features for 0064.jpg
# Extracted features for 0138.png
# Extracted features for 0068.jpg
# Extracted features for 0159.jpg
# Extracted features for 0089.jpg
# Extracted features for 0146.jpg
# Extracted features for 0085.jpg
# Extracted features for 0158.jpg
# Extracted features for 0092.jpg
# Extracted features for 0111.jpg
# Extracted features for 0127.jpg
# Extracted features for 0104.jpg
# Extracted features for 0080.jpg
# Extracted features for 0096.jpg
# Extracted features for 0154.jpg
# Extracted features for 0094.jpg
# Extracted features for 0091.jpg
# Extracted features for 0090.jpg
# Extracted features for 0069.jpg
# Extracted features for 0153.jpg
# Extracted features for 0181.jpg
# Extracted features for 0198.jpg
# Extracted features for 0237.jpg
# Extracted features for 0168.jpg
# Extracted features for 0191.jpg
# Extracted features for 0166.jpg
# Extracted features for 0186.jpg
# Extracted features for 0188.jpg
# Extracted features for 0179.jpg
# Extracted features for 0193.jpg
# Extracted features for 0233.jpg
# Extracted features for 0211.jpg
# Extracted features for 0167.jpg
# Extracted features for 0209.jpg
# Extracted features for 0247.jpg
# Extracted features for 0206.jpg
# Extracted features for 0197.jpg
# Extracted features for 0203.jpg
# Extracted features for 0175.jpg
# Extracted features for 0242.jpg
# Extracted features for 0249.jpg
# Extracted features for 0228.jpg
# Extracted features for 0177.jpg
# Extracted features for 0207.jpg
# Extracted features for 0184.jpg
# Extracted features for 0238.jpg
# Extracted features for 0221.jpg
# Extracted features for 0187.jpg
# Extracted features for 0245.jpg
# Extracted features for 0200.jpg
# Extracted features for 0225.jpg
# Extracted features for 0194.jpg
# Extracted features for 0291.jpg
# Extracted features for 0265.jpg
# Extracted features for 0332.jpg
# Extracted features for 0329.jpg
# Extracted features for 0320.jpg
# Extracted features for 0299.jpg
# Extracted features for 0307.jpg
# Extracted features for 0314.jpg
# Extracted features for 0263.jpg
# Extracted features for 0304.jpg
# Extracted features for 0340.jpg
# Extracted features for 0289.jpg
# Extracted features for 0271.jpg
# Extracted features for 0324.jpg
# Extracted features for 0296.jpg
# Extracted features for 0300.jpg
# Extracted features for 0290.jpg
# Extracted features for 0313.jpg
# Extracted features for 0255.jpg
# Extracted features for 0333.jpg
# Extracted features for 0288.jpg
# Extracted features for 0306.jpg
# Extracted features for 0283.jpg
# Extracted features for 0274.jpg
# Extracted features for 0281.jpg
# Extracted features for 0256.jpg
# Extracted features for 0341.jpg
# Extracted features for 0285.jpg
# Extracted features for 0317.jpg
# Extracted features for 0276.jpg
# Extracted features for 0292.jpg
# Extracted features for 0270.jpg
# Extracted features for 0331.jpg
# Extracted features for 0348.jpg
# Extracted features for 0523.jpg
# Extracted features for 0893.jpg
# Extracted features for 0797.jpg
# Extracted features for 0682.jpg
# Extracted features for 0450.jpg
# Extracted features for 0507.jpg
# Extracted features for 0373.jpg
# Extracted features for 0841.jpg
# Extracted features for 0597.jpg
# Extracted features for 0623.jpg
# Extracted features for 0372.jpg
# Extracted features for 0362.jpg
# Extracted features for 0446.jpg
# Extracted features for 0423.jpg
# Extracted features for 0417.jpg
# Extracted features for 0368.jpg
# Extracted features for 0822.jpg
# Extracted features for 0371.jpg
# Extracted features for 0351.jpg
# Extracted features for 0883.jpg
# Extracted features for 0711.jpg
# Extracted features for 0890.jpg
# Extracted features for 0838.jpg
# Extracted features for 0833.jpg
# Extracted features for 0453.jpg
# Extracted features for 0352.jpg
# Extracted features for 0842.jpg
# Extracted features for 0895.jpg
# Extracted features for 0366.jpg
# Extracted features for 0447.jpg
# Extracted features for 0449.jpg
# Extracted features for 0386.jpg
# Extracted features for 0424.jpg
# Extracted features for 1267.jpg
# Extracted features for 0914.jpg
# Extracted features for 1254.jpg
# Extracted features for 1258.jpg
# Extracted features for 1279.jpg
# Extracted features for 1285.jpg
# Extracted features for 1252.jpg
# Extracted features for 1283.jpg
# Extracted features for 1264.jpg
# Extracted features for 0919.jpg
# Extracted features for 1263.jpg
# Extracted features for 0954.jpg
# Extracted features for 1282.jpg
# Extracted features for 1018.jpg
# Extracted features for 0899.jpg
# Extracted features for 1256.jpg
# Extracted features for 1251.jpg
# Extracted features for 0948.jpg
# Extracted features for 1259.jpg
# Extracted features for 1270.jpg
# Extracted features for 1257.jpg
# Extracted features for 1249.jpg
# Extracted features for 1247.jpg
# Extracted features for 1274.jpg
# Extracted features for 1038.jpg
# Extracted features for 1262.jpg
# Extracted features for 1269.jpg
# Extracted features for 1245.jpg
# Extracted features for 1261.jpg
# Extracted features for 1284.jpg
# Extracted features for 1255.jpg
# Extracted features for 1248.jpg
# Extracted features for 1308.jpg
# Extracted features for 1313.jpg
# Extracted features for 1289.jpg
# Extracted features for 1306.jpg
# Extracted features for 1286.jpg
# Extracted features for 1299.jpg
# Extracted features for 1312.jpg
# Extracted features for 1290.jpg
# Extracted features for 1309.jpg
# Extracted features for 1304.jpg
# Extracted features for 1301.jpg
# Extracted features for 1291.jpg
# Extracted features for 0223.jpg
# Extracted features for 0342.jpg
# Extracted features for 0280.jpg
# Extracted features for 0248.jpg
# Extracted features for 0287.jpg
# Extracted features for 0305.jpg
# Extracted features for 0212.jpg
# Extracted features for 0354.jpg
# Extracted features for 0590.jpg
# Extracted features for 0356.jpg
# Extracted features for 0398.jpg
# Extracted features for 0395.jpg
# Extracted features for 0618.jpg
# Extracted features for 0810.jpg
# Extracted features for 0349.jpg
# Extracted features for 0748.jpg
# Extracted features for 0582.jpg
# Extracted features for 0376.jpg
# Extracted features for 0793.jpg
# Extracted features for 0739.jpg
# Extracted features for 0438.jpg
# Extracted features for 0359.jpg
# Extracted features for 0353.jpg
# Extracted features for 0581.jpg
# Extracted features for 0721.jpg
# Extracted features for 0736.jpg
# Extracted features for 0593.jpg
# Extracted features for 0734.jpg
# Extracted features for 0583.jpg
# Extracted features for 0388.jpg
# Extracted features for 0666.jpg
# Extracted features for 0596.jpg
# Extracted features for 0381.jpg
# Extracted features for 0647.jpg
# Extracted features for 0377.jpg
# Extracted features for 0396.jpg
# Extracted features for 0358.jpg
# Extracted features for 0378.jpg
# Extracted features for 0904.jpg
# Extracted features for 0815.jpg
# Extracted features for 1176.jpg
# Extracted features for 1153.jpg
# Extracted features for 0865.jpg
# Extracted features for 1165.jpg
# Extracted features for 0891.jpg
# Extracted features for 0921.jpg
# Extracted features for 1188.jpg
# Extracted features for 0820.jpg
# Extracted features for 0014.jpg
# Extracted features for 0007.jpg
# Extracted features for 0040.jpg
# Extracted features for 0017.jpg
# Extracted features for 0012.jpg
# Extracted features for 0020.jpg
# Extracted features for 0003.jpg
# Extracted features for 0018.jpg
# Extracted features for 0022.jpg
# Extracted features for 0019.jpg
# Extracted features for 0032.jpg
# Extracted features for 0041.jpg
# Extracted features for 0043.jpg
# Extracted features for 0024.jpg
# Extracted features for 0013.jpg
# Extracted features for 0001.jpg
# Extracted features for 0050.jpg
# Extracted features for 0030.jpg
# Extracted features for 0009.jpg
# Extracted features for 0039.jpg
# Extracted features for 0002.jpg
# Extracted features for 0051.jpg
# Extracted features for 0057.jpg
# Extracted features for 0070.jpg
# Extracted features for 0065.jpg
# Extracted features for 0067.jpg
# Extracted features for 0088.jpg
# Extracted features for 0108.jpg
# Extracted features for 0119.jpg
# Extracted features for 0103.jpg
# Extracted features for 0082.jpg
# Extracted features for 0113.jpg
# Extracted features for 0086.jpg
# Extracted features for 0116.jpg
# Extracted features for 0109.jpg
# Extracted features for 0061.jpg
# Extracted features for 0105.jpg
# Extracted features for 0053.jpg
# Extracted features for 0062.jpg
# Extracted features for 0117.jpg
# Extracted features for 0076.jpg
# Extracted features for 0101.jpg
# Extracted features for 0074.jpg
# Extracted features for 0060.jpg
# Extracted features for 0079.jpg
# Extracted features for 0102.jpg
# Extracted features for 0078.jpg
# Extracted features for 0110.jpg
# Extracted features for 0112.jpg
# Extracted features for 0097.jpg
# Extracted features for 0107.jpg
# Extracted features for 0100.jpg
# Extracted features for 0066.jpg
# Extracted features for 0140.jpg
# Extracted features for 0134.jpg
# Extracted features for 0120.jpg
# Extracted features for 0156.jpg
# Extracted features for 0171.jpg
# Extracted features for 0123.jpg
# Extracted features for 0157.jpg
# Extracted features for 0165.jpg
# Extracted features for 0149.jpg
# Extracted features for 0151.jpg
# Extracted features for 0121.jpg
# Extracted features for 0147.jpg
# Extracted features for 0170.jpg
# Extracted features for 0128.jpg
# Extracted features for 0169.jpg
# Extracted features for 0172.jpg
# Extracted features for 0150.png
# Extracted features for 0132.png
# Extracted features for 0162.jpg
# Extracted features for 0152.jpg
# Extracted features for 0136.png
# Extracted features for 0155.jpg
# Extracted features for 0148.jpg
# Extracted features for 0163.jpg
# Extracted features for 0137.jpg
# Extracted features for 0129.jpg
# Extracted features for 0160.jpg
# Extracted features for 0130.jpg
# Extracted features for 0124.jpg
# Extracted features for 0145.jpg
# Extracted features for 0126.jpg
# Extracted features for 0141.png
# Extracted features for 0250.jpg
# Extracted features for 0183.jpg
# Extracted features for 0205.jpg
# Extracted features for 0246.jpg
# Extracted features for 0204.jpg
# Extracted features for 0185.jpg
# Extracted features for 0258.jpg
# Extracted features for 0182.jpg
# Extracted features for 0195.jpg
# Extracted features for 0178.jpg
# Extracted features for 0208.jpg
# Extracted features for 0267.jpg
# Extracted features for 0190.jpg
# Extracted features for 0273.jpg
# Extracted features for 0196.jpg
# Extracted features for 0268.jpg
# Extracted features for 0210.jpg
# Extracted features for 0189.jpg
# Extracted features for 0214.jpg
# Extracted features for 0202.jpg
# Extracted features for 0232.jpg
# Extracted features for 0180.jpg
# Extracted features for 0231.jpg
# Extracted features for 0173.jpg
# Extracted features for 0239.jpg
# Extracted features for 0229.jpg
# Extracted features for 0174.jpg
# Extracted features for 0266.jpg
# Extracted features for 0261.jpg
# Extracted features for 0192.jpg
# Extracted features for 0176.jpg
# Extracted features for 0236.jpg
# Extracted features for 0302.jpg
# Extracted features for 0297.jpg
# Extracted features for 0301.jpg
# Extracted features for 0367.jpg
# Extracted features for 0303.jpg
# Extracted features for 0325.jpg
# Extracted features for 0284.jpg
# Extracted features for 0311.jpg
# Extracted features for 0379.jpg
# Extracted features for 0312.jpg
# Extracted features for 0316.jpg
# Extracted features for 0357.jpg
# Extracted features for 0327.jpg
# Extracted features for 0298.jpg
# Extracted features for 0326.jpg
# Extracted features for 0295.jpg
# Extracted features for 0286.jpg
# Extracted features for 0369.jpg
# Extracted features for 0294.jpg
# Extracted features for 0338.jpg
# Extracted features for 0365.jpg
# Extracted features for 0383.jpg
# Extracted features for 0370.jpg
# Extracted features for 0282.jpg
# Extracted features for 0319.jpg
# Extracted features for 0315.jpg
# Extracted features for 0308.jpg
# Extracted features for 0293.jpg
# Extracted features for 0277.jpg
# Extracted features for 0278.jpg
# Extracted features for 0346.jpg
# Extracted features for 0275.jpg
# Extracted features for 0469.jpg
# Extracted features for 0435.jpg
# Extracted features for 0430.jpg
# Extracted features for 0393.jpg
# Extracted features for 0471.jpg
# Extracted features for 0439.jpg
# Extracted features for 0458.jpg
# Extracted features for 0444.jpg
# Extracted features for 0421.jpg
# Extracted features for 0448.jpg
# Extracted features for 0428.jpg
# Extracted features for 0431.jpg
# Extracted features for 0442.jpg
# Extracted features for 0443.jpg
# Extracted features for 0434.jpg
# Extracted features for 0384.jpg
# Extracted features for 0390.jpg
# Extracted features for 0397.jpg
# Extracted features for 0418.jpg
# Extracted features for 0410.jpg
# Extracted features for 0456.jpg
# Extracted features for 0425.jpg
# Extracted features for 0440.jpg
# Extracted features for 0433.jpg
# Extracted features for 0400.jpg
# Extracted features for 0474.jpg
# Extracted features for 0419.jpg
# Extracted features for 0432.jpg
# Extracted features for 0414.jpg
# Extracted features for 0437.jpg
# Extracted features for 0436.jpg
# Extracted features for 0452.jpg
# Extracted features for 0525.jpg
# Extracted features for 0485.jpg
# Extracted features for 0526.jpg
# Extracted features for 0479.jpg
# Extracted features for 0530.jpg
# Extracted features for 0511.jpg
# Extracted features for 0509.jpg
# Extracted features for 0496.jpg
# Extracted features for 0547.jpg
# Extracted features for 0546.jpg
# Extracted features for 0529.jpg
# Extracted features for 0484.jpg
# Extracted features for 0510.jpg
# Extracted features for 0561.jpg
# Extracted features for 0531.jpg
# Extracted features for 0532.jpg
# Extracted features for 0606.jpg
# Extracted features for 0497.jpg
# Extracted features for 0564.jpg
# Extracted features for 0539.jpg
# Extracted features for 0478.jpg
# Extracted features for 0528.jpg
# Extracted features for 0520.jpg
# Extracted features for 0563.jpg
# Extracted features for 0608.jpg
# Extracted features for 0517.jpg
# Extracted features for 0609.jpg
# Extracted features for 0562.jpg
# Extracted features for 0477.jpg
# Extracted features for 0556.jpg
# Extracted features for 0554.jpg
# Extracted features for 0536.jpg
# Extracted features for 0498.jpg
# Extracted features for 0879.jpg
# Extracted features for 0897.jpg
# Extracted features for 0614.jpg
# Extracted features for 0886.jpg
# Extracted features for 0811.jpg
# Extracted features for 0857.jpg
# Extracted features for 0888.jpg
# Extracted features for 0695.jpg
# Extracted features for 0872.jpg
# Extracted features for 0729.jpg
# Extracted features for 0840.jpg
# Extracted features for 0795.jpg
# Extracted features for 0907.jpg
# Extracted features for 0762.jpg
# Extracted features for 0880.jpg
# Extracted features for 0741.jpg
# Extracted features for 0867.jpg
# Extracted features for 0902.jpg
# Extracted features for 0759.jpg
# Extracted features for 0619.jpg
# Extracted features for 0769.jpg
# Extracted features for 0887.jpg
# Extracted features for 0756.jpg
# Extracted features for 0620.jpg
# Extracted features for 0868.jpg
# Extracted features for 0844.jpg
# Extracted features for 0869.jpg
# Extracted features for 0866.jpg
# Extracted features for 0959.jpg
# Extracted features for 0929.jpg
# Extracted features for 0843.jpg
# Extracted features for 0839.jpg
# Extracted features for 1026.jpg
# Extracted features for 0960.jpg
# Extracted features for 1042.jpg
# Extracted features for 1039.jpg
# Extracted features for 1024.jpg
# Extracted features for 1051.jpg
# Extracted features for 1048.jpg
# Extracted features for 0984.jpg
# Extracted features for 0976.jpg
# Extracted features for 0987.jpg
# Extracted features for 1049.jpg
# Extracted features for 1032.jpg
# Extracted features for 1041.jpg
# Extracted features for 0970.jpg
# Extracted features for 1080.jpg
# Extracted features for 1050.jpg
# Extracted features for 1079.jpg
# Extracted features for 1047.jpg
# Extracted features for 1046.jpg
# Extracted features for 1053.jpg
# Extracted features for 1027.jpg
# Extracted features for 0979.jpg
# Extracted features for 0988.jpg
# Extracted features for 1007.jpg
# Extracted features for 0980.jpg
# Extracted features for 0982.jpg
# Extracted features for 1055.jpg
# Extracted features for 0983.jpg
# Extracted features for 0977.jpg
# Extracted features for 1025.jpg
# Extracted features for 0978.jpg
# Extracted features for 1034.jpg
# Extracted features for 1149.jpg
# Extracted features for 1088.jpg
# Extracted features for 1106.jpg
# Extracted features for 1146.jpg
# Extracted features for 1129.jpg
# Extracted features for 1192.jpg
# Extracted features for 1162.jpg
# Extracted features for 1112.jpg
# Extracted features for 1168.jpg
# Extracted features for 1109.jpg
# Extracted features for 1114.jpg
# Extracted features for 1127.jpg
# Extracted features for 1094.jpg
# Extracted features for 1157.jpg
# Extracted features for 1172.jpg
# Extracted features for 1163.jpg
# Extracted features for 1169.jpg
# Extracted features for 1145.jpg
# Extracted features for 1167.jpg
# Extracted features for 1095.jpg
# Extracted features for 1136.jpg
# Extracted features for 1122.jpg
# Extracted features for 1191.jpg
# Extracted features for 1126.jpg
# Extracted features for 1151.jpg
# Extracted features for 1147.jpg
# Extracted features for 1099.jpg
# Extracted features for 1098.jpg
# Extracted features for 1135.jpg
# Extracted features for 1159.jpg
# Extracted features for 1110.jpg
# Extracted features for 1113.jpg
# Extracted features for 1311.jpg
# Extracted features for 1276.jpg
# Extracted features for 1220.png
# Extracted features for 1275.jpg
# Extracted features for 1310.jpg
# Extracted features for 1212.jpg
# Extracted features for 1246.jpg
# Extracted features for 1307.jpg
# Extracted features for 1273.jpg
# Extracted features for 1300.jpg
# Extracted features for 1235.jpg
# Extracted features for 1197.jpg
# Extracted features for 1260.jpg
# Extracted features for 1298.jpg
# Extracted features for 1292.jpg
# Extracted features for 1265.jpg
# Extracted features for 1303.jpg
# Extracted features for 1281.jpg
# Extracted features for 1314.jpg
# Extracted features for 1239.jpg
# Extracted features for 1277.jpg
# Extracted features for 1253.jpg
# Extracted features for 1302.jpg
# Extracted features for 1234.jpg
# Extracted features for 1315.jpg
# Extracted features for 1214.jpg
# Extracted features for 1293.jpg
# Extracted features for 1237.jpg
# Extracted features for 1194.jpg
# Extracted features for 1233.jpg
# Extracted features for 1278.jpg
# Extracted features for 1200.jpg
# Extracted features for 1318.jpg
# Extracted features for 1316.jpg
# Extracted features for 1319.jpg
# Extracted features for 1322.jpg
# Extracted features for 1327.jpg
# Extracted features for 1323.jpg
# Extracted features for 1325.jpg
# Extracted features for 1324.jpg

# %% [markdown]
# traing with VISION TRANSFORMERS

# %%
# 📌 Import libraries
import os
import torch
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim

from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import roc_curve, auc, precision_recall_curve
import matplotlib.pyplot as plt
import numpy as np

# 📌 Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 📌 Dataset path
data_dir = "/content/drive/MyDrive/Autistic Children Emotions - Dr. Fatma M. Talaat/Train"

# 📌 Image transformations for ViT
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3)
])

# 📌 Load dataset
train_dataset = datasets.ImageFolder(root=data_dir, transform=transform)
class_names = train_dataset.classes
print("Classes:", class_names)

# 📌 Standard DataLoader (no balancing)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# 📌 Load pretrained Vision Transformer and modify the classification head
model = models.vit_b_16(pretrained=True)
in_features = model.heads[0].in_features
model.heads = nn.Sequential(nn.Linear(in_features, len(class_names)))  # Replace classifier
model = model.to(device)

# 📌 Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# 📌 Training loop
epochs = 10
train_loss_history = []
train_acc_history = []

for epoch in range(epochs):
    model.train()
    running_loss = 0
    correct = 0
    total = 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    epoch_loss = running_loss / len(train_loader)
    epoch_acc = 100 * correct / total
    train_loss_history.append(epoch_loss)
    train_acc_history.append(epoch_acc)

    print(f"Epoch {epoch+1}/{epochs} | Loss: {epoch_loss:.4f} | Accuracy: {epoch_acc:.2f}%")

# 📌 Evaluation and Predictions
model.eval()
all_preds = []
all_labels = []
all_probs = []

with torch.no_grad():
    for images, labels in train_loader:
        images = images.to(device)
        outputs = model(images)
        probs = torch.softmax(outputs, dim=1)

        _, preds = torch.max(probs, 1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.numpy())
        all_probs.extend(probs.cpu().numpy())

all_labels = np.array(all_labels)
all_preds = np.array(all_preds)
all_probs = np.array(all_probs)

# 📌 Classification report
print("\nClassification Report:")
print(classification_report(all_labels, all_preds, target_names=class_names))

# 📌 Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix")
plt.show()

# 📌 ROC Curve
plt.figure(figsize=(10, 6))
for i in range(len(class_names)):
    fpr, tpr, _ = roc_curve(all_labels == i, all_probs[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{class_names[i]} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curves")
plt.legend()
plt.grid(True)
plt.show()

# 📌 Precision-Recall Curve
plt.figure(figsize=(10, 6))
for i in range(len(class_names)):
    precision, recall, _ = precision_recall_curve(all_labels == i, all_probs[:, i])
    plt.plot(recall, precision, label=f'{class_names[i]}')

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curves")
plt.legend()
plt.grid(True)
plt.show()

# 📌 Loss and Accuracy Plot
epochs_range = range(1, epochs + 1)
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, train_loss_history, marker='o', label='Training Loss')
plt.title("Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(epochs_range, train_acc_history, marker='o', color='green', label='Training Accuracy')
plt.title("Training Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy (%)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Classes: ['Natural', 'anger', 'fear', 'joy', 'sadness', 'surprise']
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ViT_B_16_Weights.IMAGENET1K_V1`. You can also use `weights=ViT_B_16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vit_b_16-c867db91.pth" to /root/.cache/torch/hub/checkpoints/vit_b_16-c867db91.pth
# 100%|██████████| 330M/330M [00:06<00:00, 53.3MB/s]
# Epoch 1/10 | Loss: 1.3422 | Accuracy: 52.77%
# Epoch 2/10 | Loss: 0.9875 | Accuracy: 65.30%
# Epoch 3/10 | Loss: 0.7252 | Accuracy: 70.98%
# Epoch 4/10 | Loss: 0.5435 | Accuracy: 77.04%
# Epoch 5/10 | Loss: 0.4032 | Accuracy: 81.13%
# Epoch 6/10 | Loss: 0.3399 | Accuracy: 80.47%
# Epoch 7/10 | Loss: 0.3196 | Accuracy: 82.85%
# Epoch 8/10 | Loss: 0.3161 | Accuracy: 81.00%
# Epoch 9/10 | Loss: 0.2720 | Accuracy: 81.40%
# Epoch 10/10 | Loss: 0.2667 | Accuracy: 82.06%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Natural       1.00      1.00      1.00        48
#        anger       0.50      0.01      0.03        67
#         fear       0.69      0.30      0.42        30
#          joy       1.00      1.00      1.00       350
#      sadness       0.65      0.96      0.78       200
#     surprise       0.96      0.73      0.83        63
#
#     accuracy                           0.85       758
#    macro avg       0.80      0.67      0.68       758
# weighted avg       0.85      0.85      0.82       758

# %% [markdown]
# traing with vision transformers

# %%
# 📌 Import libraries
import os
import torch
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, WeightedRandomSampler
import torch.nn as nn
import torch.optim as optim

from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
from sklearn.preprocessing import label_binarize

import matplotlib.pyplot as plt
import numpy as np
import collections

# 📌 Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 📌 Dataset path
data_dir = "/content/drive/MyDrive/Autistic Children Emotions - Dr. Fatma M. Talaat/Train"

# 📌 Image transformations for ViT
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3)
])

# 📌 Load dataset
train_dataset = datasets.ImageFolder(root=data_dir, transform=transform)
class_names = train_dataset.classes
print("Classes:", class_names)

# 📌 Balance dataset using WeightedRandomSampler
labels = [label for _, label in train_dataset.samples]
class_counts = collections.Counter(labels)
print("Class distribution:", class_counts)

class_weights = 1. / torch.tensor([class_counts[i] for i in range(len(class_names))], dtype=torch.float)
sample_weights = [class_weights[label] for label in labels]
sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(sample_weights), replacement=True)

train_loader = DataLoader(train_dataset, batch_size=32, sampler=sampler)

# 📌 Load pretrained Vision Transformer and modify the classification head
model = models.vit_b_16(pretrained=True)
in_features = model.heads[0].in_features
model.heads = nn.Sequential(nn.Linear(in_features, len(class_names)))
model = model.to(device)

# 📌 Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# 📌 Training loop
epochs = 10
train_loss_history = []
train_acc_history = []

for epoch in range(epochs):
    model.train()
    running_loss = 0
    correct = 0
    total = 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    epoch_loss = running_loss / len(train_loader)
    epoch_acc = 100 * correct / total
    train_loss_history.append(epoch_loss)
    train_acc_history.append(epoch_acc)

    print(f"Epoch {epoch+1}/{epochs} | Loss: {epoch_loss:.4f} | Accuracy: {epoch_acc:.2f}%")

# 📌 Evaluation
model.eval()
all_preds = []
all_labels = []
all_probs = []

with torch.no_grad():
    for images, labels in train_loader:
        images = images.to(device)
        outputs = model(images)
        probs = torch.softmax(outputs, dim=1)
        _, preds = torch.max(probs, 1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.numpy())
        all_probs.extend(probs.cpu().numpy())

# 📌 Classification report
print("\nClassification Report:")
print(classification_report(all_labels, all_preds, target_names=class_names))

# 📌 Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix")
plt.show()

# 📌 Training Loss & Accuracy Plot
epochs_range = range(1, epochs + 1)
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, train_loss_history, marker='o', label='Training Loss')
plt.title("Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid(True)
plt.subplot(1, 2, 2)
plt.plot(epochs_range, train_acc_history, marker='o', color='green', label='Training Accuracy')
plt.title("Training Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy (%)")
plt.grid(True)
plt.tight_layout()
plt.show()

# 📌 ROC and Precision-Recall Curves
y_true_bin = label_binarize(all_labels, classes=range(len(class_names)))
y_score = np.array(all_probs)

# ROC Curve
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(len(class_names)):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(10, 8))
for i in range(len(class_names)):
    plt.plot(fpr[i], tpr[i], label=f"{class_names[i]} (AUC = {roc_auc[i]:.2f})")
plt.plot([0, 1], [0, 1], 'k--', label="Random")
plt.title("ROC Curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid(True)
plt.show()

# Precision-Recall Curve
precision = dict()
recall = dict()
average_precision = dict()
for i in range(len(class_names)):
    precision[i], recall[i], _ = precision_recall_curve(y_true_bin[:, i], y_score[:, i])
    average_precision[i] = average_precision_score(y_true_bin[:, i], y_score[:, i])

plt.figure(figsize=(10, 8))
for i in range(len(class_names)):
    plt.plot(recall[i], precision[i], label=f"{class_names[i]} (AP = {average_precision[i]:.2f})")
plt.title("Precision-Recall Curve")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Classes: ['Natural', 'anger', 'fear', 'joy', 'sadness', 'surprise']
# Class distribution: Counter({3: 350, 4: 200, 1: 67, 5: 63, 0: 48, 2: 30})
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ViT_B_16_Weights.IMAGENET1K_V1`. You can also use `weights=ViT_B_16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/10 | Loss: 1.4599 | Accuracy: 42.88%
# Epoch 2/10 | Loss: 0.7261 | Accuracy: 75.33%
# Epoch 3/10 | Loss: 0.5503 | Accuracy: 80.21%
# Epoch 4/10 | Loss: 0.4459 | Accuracy: 84.30%
# Epoch 5/10 | Loss: 0.4141 | Accuracy: 83.51%
# Epoch 6/10 | Loss: 0.3482 | Accuracy: 84.83%
# Epoch 7/10 | Loss: 0.3526 | Accuracy: 86.81%
# Epoch 8/10 | Loss: 0.3238 | Accuracy: 87.86%
# Epoch 9/10 | Loss: 0.3756 | Accuracy: 85.88%
# Epoch 10/10 | Loss: 0.3475 | Accuracy: 86.41%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Natural       1.00      0.94      0.97       124
#        anger       0.73      0.97      0.83       111
#         fear       0.81      0.96      0.88       136
#          joy       0.93      1.00      0.96       134
#      sadness       0.77      0.43      0.55       103
#     surprise       0.97      0.85      0.91       150
#
#     accuracy                           0.87       758
#    macro avg       0.87      0.86      0.85       758
# weighted avg       0.88      0.87      0.86       758

# %%
# 📌 Visualize Misclassified Images
import torch
import torchvision.transforms.functional as F
import matplotlib.pyplot as plt
import numpy as np
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, WeightedRandomSampler
import collections
import torch.nn as nn


# 📌 Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# 📌 Dataset path
data_dir = "/content/drive/MyDrive/Autistic Children Emotions - Dr. Fatma M. Talaat/Train"

# 📌 Image transformations for ViT
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3)
])

# 📌 Load dataset
train_dataset = datasets.ImageFolder(root=data_dir, transform=transform)
class_names = train_dataset.classes


# 📌 Balance dataset using WeightedRandomSampler
labels = [label for _, label in train_dataset.samples]
class_counts = collections.Counter(labels)

class_weights = 1. / torch.tensor([class_counts[i] for i in range(len(class_names))], dtype=torch.float)
sample_weights = [class_weights[label] for label in labels]
sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(sample_weights), replacement=True)

train_loader = DataLoader(train_dataset, batch_size=32, sampler=sampler)


# 📌 Load pretrained Vision Transformer and modify the classification head
model = models.vit_b_16(pretrained=True)
in_features = model.heads[0].in_features
model.heads = nn.Sequential(nn.Linear(in_features, len(class_names)))
model = model.to(device)


misclassified = []

# Reload images and labels from the loader
model.eval() # Set model to evaluation mode
with torch.no_grad():
    for images, labels in train_loader:
        images = images.to(device) # Move images to GPU
        outputs = model(images)
        probs = torch.softmax(outputs, dim=1)
        _, preds = torch.max(probs, 1)

        for i in range(len(labels)):
            if preds[i] != labels[i]:
                misclassified.append((images[i].cpu(), preds[i].cpu(), labels[i].cpu()))

# 📌 Show few misclassified examples


plt.figure(figsize=(12, 12))
for idx, (img, pred, label) in enumerate(misclassified[:16]):
    img = F.to_pil_image((img * 0.5 + 0.5))  # unnormalize for display
    plt.subplot(4, 4, idx + 1)
    plt.imshow(img)
    plt.title(f"Pred: {class_names[pred]}\nActual: {class_names[label]}")
    plt.axis("off")
plt.suptitle("Misclassified Samples", fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ViT_B_16_Weights.IMAGENET1K_V1`. You can also use `weights=ViT_B_16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vit_b_16-c867db91.pth" to /root/.cache/torch/hub/checkpoints/vit_b_16-c867db91.pth
# 100%|██████████| 330M/330M [00:05<00:00, 62.3MB/s]

# %%
import matplotlib.pyplot as plt
import collections
from torchvision import datasets

# Dataset path
data_dir = "/content/drive/MyDrive/Autistic Children Emotions - Dr. Fatma M. Talaat/Train"

# Load dataset (only to get class distribution)
train_dataset = datasets.ImageFolder(root=data_dir)
class_names = train_dataset.classes
labels = [label for _, label in train_dataset.samples]
class_counts = collections.Counter(labels)

# Create bar graph
plt.figure(figsize=(10, 6))
plt.bar(class_names, [class_counts[i] for i in range(len(class_names))])
plt.xlabel("Emotion Class")
plt.ylabel("Number of Images")
plt.title("Distribution of Images per Emotion Class")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
